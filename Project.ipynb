# %%
import pandas as pd
import altair as alt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Derrick Mayall\5122_Vis_Analytics\Streamlit_Project\Human-Trafficking-Analysis\Project.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Derrick%20Mayall/5122_Vis_Analytics/Streamlit_Project/Human-Trafficking-Analysis/Project.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Derrick%20Mayall/5122_Vis_Analytics/Streamlit_Project/Human-Trafficking-Analysis/Project.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import altair as alt
#       <a href='vscode-notebook-cell:/c%3A/Users/Derrick%20Mayall/5122_Vis_Analytics/Streamlit_Project/Human-Trafficking-Analysis/Project.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import seaborn as sns
#
# ModuleNotFoundError: No module named 'altair'

# %%
data = pd.read_csv('Trafficking_Data.csv')
data
# Out:
#         yearOfRegistration gender ageBroad majorityStatusAtExploit  \
# 0                   2015.0   Male   30--38                     NaN
# 1                   2015.0   Male   30--38                     NaN
# 2                   2015.0   Male   30--38                     NaN
# 3                   2015.0   Male   30--38                     NaN
# 4                   2015.0   Male   30--38                     NaN
# ...                    ...    ...      ...                     ...
# 193020              2019.0    NaN      NaN                     NaN
# 193021              2019.0    NaN      NaN                     NaN
# 193022              2019.0    NaN      NaN                     NaN
# 193023              2019.0    NaN      NaN                     NaN
# 193024              2019.0    NaN      NaN                     NaN
#
#           traffickMonths citizenship CountryOfExploitation  \
# 0       13--24 (1-2 yrs)         UKR                   RUS
# ...

# %%
gender_counts = data.groupby('gender')['gender'].count().reset_index(name='count')
